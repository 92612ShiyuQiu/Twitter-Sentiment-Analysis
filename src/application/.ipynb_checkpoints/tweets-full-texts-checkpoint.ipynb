# %%
import tweepy as tw
import os
import pandas as pd
import json

#To access the Twitter API, you will need 4 things from the your Twitter App page. 
#These keys are located in your Twitter app settings in the Keys and Access Tokens tab.
consumer_key= 'wnFgrbwPDAwJA1vCS8EZVfiP7'
consumer_secret= 'cHUSVJZQtkhU6w05pBPROGZ1yAahHakL8pSJEr5jIhkDJvXElo'
access_token= '1203090107957309440-jrv0gUebcBjNvqlml26PdLYG5Kibgk'
access_token_secret= 'iD74htxVkMRnxN8I8dFwmsuGsukbOSaslfL1UqK8HHgtB'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_word4 = "#coronavirus" + " -filter:retweets" # #soleimanikilling
tweetsObj4 = tw.Cursor(api.search,
                       tweet_mode='extended',
                   q = search_word4,
                   lang = "en",
                   since = "2020-01-01").items(1000)
tweets4 = []
tweets4.extend(tweetsObj4)
tweets4_json_strs = [json.dumps(tweet._json) for tweet in tweets4]
tweets4_full_text = [json.loads(json_str)["full_text"] for json_str in tweets4_json_strs]
print(tweets4_full_text[:5])

# %%
tweet_pandas4 = pd.DataFrame(data = tweets4_full_text, columns=['text'])
tweet_pandas4.to_csv(r'../application_dataset/coronavirus1.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-68f21bed06ea> in <module>
# ----> 1 print(tweetsObj4.keys())
#
# AttributeError: 'ItemIterator' object has no attribute 'keys'

# %%
tweets4 = []#[tweet.text for tweet in tweetsObj4]
tweets4.extend(tweetsObj4)
print(tweets4[:20])
print(len(tweets4))
tweet_pandas4 = pd.DataFrame(data = tweets4, columns=['text'])
tweet_pandas4.to_csv(r'../application_dataset/coronavirus1.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-fd9a5586960f> in <module>
#       1 tweets4 = []#[tweet.text for tweet in tweetsObj4]
# ----> 2 tweets4.extend(tweetsObj4)
#       3 print(tweets4[:20])
#       4 print(len(tweets4))
#       5 tweet_pandas4 = pd.DataFrame(data = tweets4, columns=['text'])
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     113             # This is a special invocation that returns the underlying
#     114             # APIMethod class
# --> 115             model = ModelParser().parse(self.method(create=True), data)
#     116             if hasattr(self.method, '__self__'):
#     117                 self.method.__self__.parser = old_parser
#
# ~\Anaconda3\lib\site-packages\tweepy\parsers.py in parse(self, method, payload)
#      98             result = model.parse_list(method.api, json)
#      99         else:
# --> 100             result = model.parse(method.api, json)
#     101
#     102         if cursors:
#
# ~\Anaconda3\lib\site-packages\tweepy\models.py in parse(cls, api, json)
#     303         results.next_results = metadata.get('next_results')
#     304
# --> 305         status_model = getattr(api.parser.model_factory, 'status') if api else Status
#     306
#     307         for status in json['statuses']:
#
# AttributeError: 'JSONParser' object has no attribute 'model_factory'

# %%
#tweets4 = []#[tweet.text for tweet in tweetsObj4]
#tweets4.extend(tweetsObj4)
#print(type(json.dumps(tweets4[0]._json)))
tweets4_json_strs = [json.dumps(tweet._json) for tweet in tweets4]
#json_str = json.dumps(tweets4[0]._json)
#parsed = json.loads(json_str)
tweets4_full_text = [json.loads(json_str)["full_text"] for json_str in tweets4_json_strs]
#print(type(json_result))
#print(parsed["full_text"])
print(tweets4_full_text[:5])
# Out:
# ['Announce a date in 1 month to go on a total 3 week lockdown with only essential public workers/hospitals open, to allow for enough prep time. Then the whole world goes into a mini hibernation. Just cut it off and get it done with. \n#COVIDー19 #coronapocolypse #coronavirus', '#Coronavirus: Small Business Administration ( @SBAgov ) Loan Information Emerges - @ChannelE2E https://t.co/wfbd0jetGS https://t.co/sYXUBlMo1B', 'The latest The #Travel Daily! https://t.co/4yQNHO0QKu #selfisolating #coronavirus', 'Luke, stop touching your face, you’ll get #coronavirus #ESBlive', 'During hard times, everyone needs to do their part. From their headquarters in Sydney, Australia, UCOT is doing theirs by using their #blockchain to mitigate the COVID-19. #blockchain #covid19 #coronavirus https://t.co/Vnf1DChK4K https://t.co/iwmSCSKLwp']

# %%
print(len(tweets4))
print(tweets4[:5])
# Out:
# 1000
# [Status(_api=<tweepy.api.API object at 0x000001BCA5C6A5C8>, _json={'created_at': 'Mon Mar 16 00:12:03 +0000 2020', 'id': 1239343634585210885, 'id_str': '1239343634585210885', 'full_text': 'Announce a date in 1 month to go on a total 3 week lockdown with only essential public workers/hospitals open, to allow for enough prep time. Then the whole world goes into a mini hibernation. Just cut it off and get it done with. \n#COVIDー19 #coronapocolypse #coronavirus', 'truncated': False, 'display_text_range': [0, 271], 'entities': {'hashtags': [{'text': 'COVIDー19', 'indices': [232, 241]}, {'text': 'coronapocolypse', 'indices': [242, 258]}, {'text': 'coronavirus', 'indices': [259, 271]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 98055090, 'id_str': '98055090', 'name': 'David Riley Jr.', 'screen_name': 'DavidRiley1989', 'location': 'Lynn, MA', 'description': 'Some guy from some city on some planet floating through some solar system in some galaxy in the endless expanse that is the universe', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 102, 'friends_count': 100, 'listed_count': 2, 'created_at': 'Sun Dec 20 05:11:34 +0000 2009', 'favourites_count': 748, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1902, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/725801234117066752/2IcLH1xl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/725801234117066752/2IcLH1xl_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/98055090/1461879452', 'profile_link_color': '005780', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 3, 16, 0, 12, 3), id=1239343634585210885, id_str='1239343634585210885', full_text='Announce a date in 1 month to go on a total 3 week lockdown with only essential public workers/hospitals open, to allow for enough prep time. Then the whole world goes into a mini hibernation. Just cut it off and get it done with. \n#COVIDー19 #coronapocolypse #coronavirus', truncated=False, display_text_range=[0, 271], entities={'hashtags': [{'text': 'COVIDー19', 'indices': [232, 241]}, {'text': 'coronapocolypse', 'indices': [242, 258]}, {'text': 'coronavirus', 'indices': [259, 271]}], 'symbols': [], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001BCA5C6A5C8>, _json={'id': 98055090, 'id_str': '98055090', 'name': 'David Riley Jr.', 'screen_name': 'DavidRiley1989', 'location': 'Lynn, MA', 'd ...
