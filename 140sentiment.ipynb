# %%
import pandas as pd

features = pd.read_csv(r"140sentiment/features.csv", engine='python')

# %%
features = features[features.columns[1]]

# %%
features = features.values.tolist()

# %%
features
# Out:
# ['actually',
#  'already',
#  'also',
#  'always',
#  'amaze',
#  'amp',
#  'another',
#  'anything',
#  'around',
#  'away',
#  'awesome',
#  'aww',
#  'baby',
#  'back',
#  'bad',
#  'beautiful',
#  'bed',
#  'best',
#  'better',
#  'big',
#  'birthday',
#  'bite',
#  'book',
#  'bore',
#  'break',
#  'buy',
#  'call',
#  'cant',
#  'car',
#  'check',
#  'cold',
#  'com',
#  'come',
#  'cool',
#  'could',
#  'cry',
#  'damn',
#  'day',
#  'days',
#  'die',
#  'do',
#  'dont',
#  'drink',
#  'early',
#  'eat',
#  'end',
#  'enjoy',
#  'even',
#  'ever',
#  'everyone',
#  'excite',
#  'feel',
#  'finally',
#  'find',
#  'finish',
#  'first',
#  'follow',
#  'forget',
#  'friday',
#  'friend',
#  'friends',
#  'fuck',
#  'fun',
#  'game',
#  'get',
#  'girl',
#  'give',
#  'glad',
#  'go',
#  'god',
#  'gonna',
#  'good',
#  'gotta',
#  'great',
#  'guess',
#  'guy',
#  'haha',
#  'happen',
#  'happy',
#  'hard',
#  'hate',
#  'head',
#  'hear',
#  'help',
#  'hey',
#  'hi',
# ...
